# %%
import requests
import pandas as pd
import polars as pl
#import json

# %%
# Funktion zum Abrufen und Verarbeiten der Spieldaten
def process_game(game_id, api_key):
    # Endpunkte definieren
    drives_url = f"https://main-api-1.sportapp.fi/api/v1/public/match-drives?id={game_id}&apikey={api_key}"
    match_url = f"https://main-api-1.sportapp.fi/api/v1/public/match-v1?id={game_id}&apikey={api_key}"
    
    # Drives-Daten abrufen
    drives_response = requests.get(drives_url)
    if drives_response.status_code != 200:
        print(f"Fehler beim Abrufen der Drives-Daten für Spiel {game_id}")
        return None
    
    # Match-Daten abrufen
    match_response = requests.get(match_url)
    if match_response.status_code != 200:
        print(f"Fehler beim Abrufen der Match-Daten für Spiel {game_id}")
        return None
    
    drives_data = drives_response.json()
    match_data = match_response.json()
    
    # Home- und Away-Team-Informationen extrahieren
    series_id = match_data.get("series", {}).get("id", 0)
    series_region = match_data.get("series", {}).get("region", 0)
    series_level = match_data.get("series", {}).get("level", 0)
    season = match_data.get("series", {}).get("seasonName", 0)
    gender = match_data.get("series", {}).get("id", 0)
    game_type = match_data.get("series", {}).get("phase", 0)
    game_group_id = match_data.get("series", {}).get("groupId", 0)
    game_group = match_data.get("series", {}).get("groupName", 0)
    game_type = match_data.get("series", {}).get("phase", 0)
    stream_url = match_data.get("streams", [{}])[0].get("url", "Unknown") if match_data.get("streams") else "Unknown"
    home_team = match_data.get("home", {}).get("id", "Unknown")
    away_team = match_data.get("away", {}).get("id", "Unknown")
    
    # Ergebnisdaten überprüfen und abrufen
    result_data = match_data.get("result")
    if result_data is None:
        print(f"Keine Ergebnisdaten verfügbar für Spiel {game_id}.")
        home_score = 0
        away_score = 0
    else:
        home_score = result_data.get("details", {}).get("points_total_home", 0)
        away_score = result_data.get("details", {}).get("points_total_away", 0)
    
    plays_data = []
    
    # Verarbeitung der Drives und Plays
    for drive in drives_data:
        half = drive.get("num") + 1
        for event_group_index, event_group in enumerate(drive.get("drives", [])):
            drive_id = event_group_index + 1
            team_id = event_group.get("team", {}).get("id", "Unknown")
            team_abb = event_group.get("team", {}).get("threeLetters", "Unknown")
            for play_index, play in enumerate(event_group.get("eventGroups", [])):
                play_id = play_index + 1
                plays_data.append({
                    "season": season,
                    "competition_id": series_id,
                    "competition_name": series_region,
                    "competition_league": series_level,
                    "gender": gender,
                    "game_id": game_id,
                    "game_type": game_type,
                    "game_group_id": game_group_id,
                    "game_group": game_group,
                    "half": half,
                    "drive_id_half": drive_id,
                    "play_id_drive": play_id,
                    "posteam_id": team_id,
                    "posteam_abb": team_abb,
                    "summary": play.get("summary"),
                    "action_title": play.get("actionTitle"),
                    "down": play.get("down"),
                    "down_desc": play.get("downLabel"),
                    "down_after": play.get("nextDown"),
                    "down_after_desc": play.get("nextDownLabel"),
                    "yards_to_go": play.get("target"),
                    "yards_to_go_after": play.get("nextTarget"),
                    "yards": event_group.get("yards"),
                    "start_yard_line": play.get("startYardLine", {}).get("yardLine", 0),
                    "start_yard_line_team_half_id": play.get("startYardLine", {}).get("team", 0),
                    "end_yard_line": play.get("endYardLine", {}).get("yardLine", 0),
                    "end_yard_line_team_half_id": play.get("endYardLine", {}).get("team", 0),
                    "possession_time": event_group.get("timeOfPossession"),
                    "home_team": home_team,
                    "away_team": away_team,
                    "home_score": home_score,
                    "away_score": away_score,
                    "stream_url": stream_url
                })
    
    return plays_data

# %%
# Mehrere Spiele abrufen
def process_games(game_ids, api_key):
    all_plays = []
    for game_id in game_ids:
        print(f"Verarbeite Spiel ID: {game_id}")
        game_plays = process_game(game_id, api_key)
        if game_plays:
            all_plays.extend(game_plays)
        print(f"Fertig mit Spiel ID: {game_id}")
    
    # DataFrame erstellen
    return pd.DataFrame(all_plays)

# %%
def fetch_team_players(team_ids, api_key):
    all_players_data = []
    
    for team_id in team_ids:
        api_url = f"https://main-api-1.sportapp.fi/api/v1/public/teams-players?team={team_id}&apikey={api_key}"
        print(f"Fetching data for team ID: {team_id}")

        try:
            response = requests.get(api_url)
            response.raise_for_status()  # Check for HTTP request errors
            data = response.json()  # Attempt to parse JSON

            if isinstance(data, list) and len(data) > 0 and "players" in data[0]:  # Ensure 'players' key exists in response
                team_name = data[0]["name"]
                players = data[0]["players"]
                
                for player in players:
                    player_info = {
                        "Team": team_name,
                        "Player ID": player["id"],
                        "Name": player["name"],
                        "Uniform Number": player["uniform_number"],
                        "Position": player["position"],
                        "Club": player["club"]
                    }
                    all_players_data.append(player_info)
                print(f"Successfully fetched data for team ID {team_id} ({team_name})")
            else:
                print(f"No players found for team ID: {team_id} or invalid response format.")

        except requests.JSONDecodeError:
            print(f"Skipping team ID: {team_id} - Response is not in JSON format.")
        except requests.RequestException as e:
            print(f"Request failed for team ID: {team_id} with error: {e}")
    
    players_df = pl.DataFrame(all_players_data)
    return players_df

# %%
### utils

def convert_to_polars(df: pd.DataFrame) -> pl.DataFrame:
    df['yards_to_go'] = df['yards_to_go'].astype(str)
    df['yards_to_go_after'] = df['yards_to_go_after'].astype(str)
    
    df = pl.from_pandas(df)

    return df

def extract_players_from_summary(df: pd.DataFrame) -> pd.DataFrame:
    # Regular Expressions für die verschiedenen Fälle
    passer_pattern = r'#(\d+)\s+(\w+\s\w+)\s+pass'  # Identifikation des Passers
    receiver_pattern = r'pass complete to #(\d+)\s+(\w+\s\w+)'  # Identifikation des Receivers
    rusher_pattern = r'#(\d+)\s+(\w+\s\w+)\s+rush'  # Identifikation des Rushers
    tackle_pattern = r'tackled by #(\d+)\s+(\w+\s\w+)'  # Identifikation des Tacklers
    interception_pattern = r'pass intercepted to #(\d+)\s+(\w+\s\w+)'  # Identifikation des Interceptionsspielers
    sack_pattern = r'sacked by #(\d+)\s+(\w+\s\w+)'
    play_result_pattern = r'(rush|complete|incomplete|touchdown|first down|intercepted|sack|fumble|good|miss|timeout)'
    penalty_pattern = r'(penalty)'
    safety_pattern = r'(safety)'

    # Funktionen zur Extraktion der Spieler
    def get_passer(summary):
        match = re.search(passer_pattern, summary)
        return match.group(1) if match else None
    
    def get_receiver(summary):
        match = re.search(receiver_pattern, summary)
        return match.group(1) if match else None

    def get_rusher(summary):
        match = re.search(rusher_pattern, summary)
        return match.group(1) if match else None

    def get_tackle_player(summary):
        match = re.search(tackle_pattern, summary)
        return match.group(1) if match else None

    def get_interception_player(summary):
        match = re.search(interception_pattern, summary)
        return match.group(1) if match else None
    
    def get_sack_player(summary):
        match = re.search(sack_pattern, summary)
        return match.group(1) if match else None

    def get_play_result(summary):
        match = re.search(play_result_pattern, summary)
        return match.group(1) if match else None

    def get_penalty(summary):
        match = re.search(penalty_pattern, summary)
        return match.group(1) if match else None

    def get_safety(summary):
        match = re.search(safety_pattern, summary)
        return match.group(1) if match else None

    # Die neuen Spalten hinzufügen
    df['passer'] = df['summary'].apply(get_passer)
    df['receiver'] = df['summary'].apply(get_receiver)
    df['rusher'] = df['summary'].apply(get_rusher)
    df['tackle_player'] = df['summary'].apply(get_tackle_player)
    df['interception_player'] = df['summary'].apply(get_interception_player)
    df['sack_player'] = df['summary'].apply(get_sack_player)
    df['play_result'] = df['summary'].apply(get_play_result)
    df['penalty'] = df['summary'].apply(get_penalty)
    df['safety'] = df['summary'].apply(get_safety)

    return df

def clean_sort(df: pd.DataFrame) -> pd.DataFrame:
    """
    Sorts the DataFrame based on the specified columns with the given order.
    
    Parameters:
    df (pd.DataFrame): The DataFrame to be sorted.
    
    Returns:
    pd.DataFrame: The sorted DataFrame.
    """
    df = df.sort_values(by=['game_id','half', 'drive_id_half', 'play_id_drive'], ascending=[True, True, False, False])
    return df

def clean_yardage(df: pl.DataFrame) -> pl.DataFrame:
    """
    Computes the 'yardline_50' column based on the 'start_yard_line_team_half_desc' and 'start_yard_line' columns and the yards_to_go column based on original column.
    
    Parameters:
    df (pd.DataFrame): The DataFrame to be processed.
    
    Returns:
    pl.DataFrame: The DataFrame with the 'yardline_50' column added.
    """ 
    df = (
        df
        .with_columns(
            yardline_50 = pl.when(pl.col("start_yard_line_team_half_id")==pl.col("away_team")).then(50-pl.col("start_yard_line")).otherwise(pl.col("start_yard_line")),
            yardline_50_after = pl.when(pl.col("end_yard_line_team_half_id")==pl.col("away_team")).then(50-pl.col("end_yard_line")).otherwise(pl.col("end_yard_line"))
        )
        .with_columns(
            yardline_50 = pl.when(pl.col("posteam")==pl.col("home_team"))
            .then(pl.col("yardline_50"))
            .when(pl.col("posteam")==pl.col("away_team"))
            .then(50-pl.col("yardline_50"))
            .otherwise(pl.lit(0)),
            yardline_50_after = pl.when(pl.col("posteam")==pl.col("home_team"))
            .then(pl.col("yardline_50_after"))
            .when(pl.col("posteam")==pl.col("away_team"))
            .then(50-pl.col("yardline_50_after"))
            .otherwise(pl.lit(0))
        )
        .with_columns(yards_gained = pl.col("yardline_50_after") - pl.col("yardline_50"))
        .with_columns(
            yards_to_go = pl.when(pl.col("yards_to_go")=="G").then(pl.lit(999))
            .when(pl.col("yards_to_go").is_null()).then(pl.lit(None))
            .when(pl.col("yards_to_go")=="").then(pl.lit(None))
            .when(pl.col("down_desc")=="PAT 5 yards").then(pl.lit(5))
            .when(pl.col("down_desc")=="PAT 10 yards").then(pl.lit(10))
            .otherwise(pl.col("yards_to_go")),
            yards_to_go_after = pl.when(pl.col("yards_to_go_after")=="G").then(pl.lit(999))
            .when(pl.col("yards_to_go_after").is_null()).then(pl.lit(None))
            .when(pl.col("yards_to_go_after")=="").then(pl.lit(None))
            .otherwise(pl.col("yards_to_go_after"))
        )
        .with_columns(
            pl.col("yards_to_go").cast(pl.Int32),
            pl.col("yards_to_go_after").cast(pl.Int32)
            )
        .with_columns(
            yards_to_go = pl.when(pl.col("yards_to_go")==999)
            .then(50-pl.col("yardline_50"))
            .otherwise(pl.col("yards_to_go")),
            yards_to_go_after = pl.when(pl.col("yards_to_go_after")==999)
            .then(50-pl.col("yardline_50_after"))
            .otherwise(pl.col("yards_to_go_after"))
        )
        .with_columns(
            yards_to_go_simple = 
                    pl.when(pl.col("yards_to_go") <= 5).then(pl.lit(1))
                    .when((pl.col("yards_to_go") > 5) & (pl.col("yards_to_go") <= 10)).then(pl.lit(2))
                    .when((pl.col("yards_to_go") > 10) & (pl.col("yards_to_go") <= 15)).then(pl.lit(3))
                    .when((pl.col("yards_to_go") > 15) & (pl.col("yards_to_go") <= 20)).then(pl.lit(4))
                    .when(pl.col("yards_to_go") > 20).then(pl.lit(5))
                    .otherwise(pl.lit(0))
        )
        .with_columns(
            first_down = 
                pl.when((pl.col('yardline_50') < 25) & (pl.col("yards_gained") > pl.col("yards_to_go"))).then(pl.lit(1))
                .otherwise(pl.lit(0))
        )
    )

    return df

def correct_posteam(df: pl.DataFrame) -> pl.DataFrame:

    df = df.with_columns(posteam_helper = pl.concat_str(pl.col("game_id"),pl.lit("_"),pl.col("drive_id")))

    filter_drive = df.select(pl.col('posteam_helper').filter(pl.col('def_touchdown')==1)).unique()
    
    df = (df
          .with_columns(
              defteam_id =
                pl.when(pl.col("posteam_id") == pl.col("home_team")).then(pl.col("away_team"))
                .when(pl.col("posteam_id") == pl.col("away_team")).then(pl.col("home_team"))
                .otherwise(pl.lit(None))
              )
          .with_columns(posteam_helper_2 = pl.when((pl.col("posteam_helper")).is_in(filter_drive)).then(pl.col("play_id")).otherwise(pl.lit(None)))
          .with_columns(posteam_helper_3 = pl.when((pl.col("posteam_helper")).is_in(filter_drive)).then(pl.col("posteam_helper")).otherwise(pl.lit(None)))
          .with_columns(posteam_helper_max = pl.when(((pl.col("play_id"))==(pl.col("posteam_helper_2")))&pl.col("def_touchdown")==1).then(pl.col("posteam_helper")).otherwise(pl.lit(None)))
          .with_columns(posteam_helper_max = pl.col("posteam_helper_max").backward_fill())
          .with_columns(posteam = pl.when((pl.col("posteam_helper_3"))==(pl.col("posteam_helper_max"))).then(pl.col("defteam_id")).otherwise(pl.col("posteam_id")))
          .with_columns(
              defteam =
                pl.when(pl.col("posteam") == pl.col("home_team")).then(pl.col("away_team"))
                .when(pl.col("posteam") == pl.col("away_team")).then(pl.col("home_team"))
                .otherwise(pl.lit(None))
              )
          .drop(["posteam_helper","posteam_helper_2","posteam_helper_3","posteam_helper_max","posteam_id","defteam_id"])
          .with_columns(posteam_after = pl.col("posteam").shift(-1))
          .with_columns(defteam_after = pl.col("defteam").shift(-1))
          )
    
    return df

def clean_play_ids(df: pl.DataFrame) -> pl.DataFrame:
    """
    Computes the 'play_id', 'drive_id' and 'half_end' columns based on the sorted index outputs of the clean_sort function.
    
    Parameters:
    df (pd.DataFrame): The DataFrame to be processed.
    
    Returns:
    pl.DataFrame: The DataFrame with the 'drive_id', 'play_id' and 'half_end' column added.
    """ 
    df = (
        df
        .with_row_index(offset=1)
        .with_columns(
            drive_id = (pl.col("drive_id_half").diff() != 0).cum_sum().over("game_id"),
            play_id = (pl.col("index").diff() != 0).cum_sum().over("game_id")
            )
        .with_columns(
            drive_id = (pl.col("drive_id")+1).backward_fill(),
            play_id = (pl.col("play_id")+1),
            )
        .with_columns(
            play_id = pl.when(pl.col("play_id").is_null()).then(pl.lit(1)).otherwise(pl.col("play_id")),
            play_id_max_half = pl.col("play_id").max().over(["game_id","half"]),
            play_id_max = pl.col("play_id").max().over("game_id")
        )
        .with_columns(
            half_end = 
            pl.when(pl.col("play_id_max_half")==pl.col("play_id"))
            .then(pl.lit(1))
            .when(pl.col("play_id_max")==pl.col("play_id"))            
            .then(pl.lit(1))
            .otherwise(pl.lit(0))
            )
        .drop(["play_id_max_half", "play_id_max"])
    )
    return df

def add_event_columns(df: pl.DataFrame) -> pl.DataFrame:
    """
    Computes the event columns mainly based on the 'summary', 'play_result' and 'penalty' columns.
    
    Parameters:
    df (pd.DataFrame): The DataFrame to be processed.
    
    Returns:
    pl.DataFrame: The DataFrame with the event columns like 'touchdown' or 'interception' added.
    """ 
    df = (
        df
        .with_columns(
            down = pl.when(pl.col("down_desc").str.contains("PAT")).then(pl.lit(0)).otherwise(pl.col("down")),
            play_type = 
                pl.when(pl.col("play_result") == "rush").then(pl.lit("rush"))
                .when(pl.col("play_result").is_in(["complete","incomplete","sack","intercepted","good","miss"])).then(pl.lit("pass"))
                .when(pl.col("play_result").is_in(["timeout"])).then(pl.lit("no_play"))
                .when(pl.col("play_result").is_null()).then(pl.lit("no_play"))
                .otherwise(pl.lit(None)), 
            complete_pass = pl.when(pl.col("play_result") == "complete").then(pl.lit(1)).otherwise(pl.lit(0)),
            interception = pl.when(pl.col("play_result") == "intercepted").then(pl.lit(1)).otherwise(pl.lit(0)),
            touchdown = pl.when(pl.col("action_title") == "Touchdown").then(pl.lit(1)).otherwise(pl.lit(0)),
            point_after = pl.when(pl.col("down_desc").str.contains("PAT")).then(pl.lit(1)).otherwise(pl.lit(0)),
            point_after_success = pl.when(pl.col("play_result") == "good").then(pl.lit(1)).otherwise(pl.lit(0)),
            safety = pl.when(pl.col("safety") == "safety").then(pl.lit(1)).otherwise(pl.lit(0)),
            penalty = pl.when(pl.col("penalty") == "penalty").then(pl.lit(1)).otherwise(pl.lit(0))
        )
        .with_columns(
            def_touchdown = 
                pl.when((pl.col('interception') == 1) & (pl.col("touchdown")==1)).then(pl.lit(1))
                .otherwise(pl.lit(0)),
            one_point_conv_success =
                pl.when((pl.col('point_after_success') == 1) & (pl.col('point_after') == 1) & (pl.col("down_desc") == "PAT 5 yards")).then(pl.lit(1))
                .otherwise(pl.lit(0)),
            two_point_conv_success =
                pl.when((pl.col('point_after_success') == 1) & (pl.col('point_after') == 1) & (pl.col("down_desc") == "PAT 10 yards")).then(pl.lit(1))
                .otherwise(pl.lit(0)),
            defensive_two_point_conv =
                pl.when((pl.col('point_after') == 1) & (pl.col("interception") == 1) & (pl.col("touchdown") == 1))
                .then(pl.lit(1))
                .otherwise(pl.lit(0))
        )
        .with_columns(touchdown = pl.when((pl.col("def_touchdown")==1)|(pl.col("point_after")==1)).then(pl.lit(0)).otherwise(pl.col("touchdown")))
        .with_columns(
            scoring_play = 
                pl.when(
                    pl.col('touchdown') |
                    pl.col('def_touchdown') |
                    pl.col('one_point_conv_success') |
                    pl.col('two_point_conv_success') |
                    pl.col('defensive_two_point_conv') |
                    pl.col('safety') 
                    == 1)
                .then(pl.lit(1))
                .otherwise(pl.lit(0))
        )
    )
    return df

def add_scoring_play_team(df: pl.DataFrame) -> pl.DataFrame:
    df = df.with_columns(
        scoring_play_team =
            pl.when((pl.col('scoring_play') == 1) & (pl.col("touchdown") | pl.col("one_point_conv_success") | pl.col("two_point_conv_success") == 1)).then(pl.col("posteam"))
            .when((pl.col('scoring_play') == 1) & (pl.col("def_touchdown") | pl.col("defensive_two_point_conv") | pl.col("safety") == 1)).then(pl.col("defteam"))
            .otherwise(pl.lit(None))
            .alias('scoring_play_team')
        )
    
    return df

def add_team_points(df: pl.DataFrame) -> pl.DataFrame:
    df = (df
          .with_columns(
              home_team_points = pl.when(pl.col("play_id")==1).then(pl.lit(0))
              .when(pl.col('home_team')==pl.col("scoring_play_team"))
              .then(
                  pl.when(touchdown=1).then(pl.lit(6))
                  .when(def_touchdown=1).then(pl.lit(6))
                  .when(one_point_conv_success=1).then(pl.lit(1))
                  .when(two_point_conv_success=1).then(pl.lit(2))
                  .when(defensive_two_point_conv=1).then(pl.lit(2))
                  .when(safety=1).then(pl.lit(2))
                .otherwise(pl.lit(None))
                ),
              away_team_points = pl.when(pl.col("play_id")==1).then(pl.lit(0))
              .when(pl.col('away_team')==pl.col("scoring_play_team")).then(
                  pl.when(touchdown=1).then(pl.lit(6))
                  .when(def_touchdown=1).then(pl.lit(6))
                  .when(one_point_conv_success=1).then(pl.lit(1))
                  .when(two_point_conv_success=1).then(pl.lit(2))
                  .when(defensive_two_point_conv=1).then(pl.lit(2))
                  .when(safety=1).then(pl.lit(2))
                .otherwise(pl.lit(None))
                )
                )
                .with_columns(
                    home_team_score = pl.col('home_team_points').cum_sum().over(["game_id","home_team"]),
                    away_team_score = pl.col('away_team_points').cum_sum().over(["game_id","away_team"])
                )
                .with_columns(
                        home_team_score = pl.col("home_team_score").forward_fill(),
                        away_team_score = pl.col("away_team_score").forward_fill()
                    )
                .with_columns(
                    posteam_score = pl.when(pl.col("posteam") == pl.col("home_team")).then(pl.col('home_team_score'))
                        .when(pl.col("posteam") == pl.col("away_team")).then(pl.col('away_team_score')),
                    defteam_score = pl.when(pl.col("defteam") == pl.col("home_team")).then(pl.col('home_team_score'))
                        .when(pl.col("defteam") == pl.col("away_team")).then(pl.col('away_team_score'))
                    )
                .with_columns(score_differential = pl.col("posteam_score") - pl.col("defteam_score"))
          )
    
    return df

def drop_cols(df: pl.DataFrame) -> pl.DataFrame:
    cols_to_drop = ["drive_id_half","play_id_drive","posteam_abb","yards","start_yard_line","start_yard_line_team_half_id","end_yard_line","end_yard_line_team_half_id"]

    df = df.drop(cols_to_drop)

    return df

# %%
# Beispielnutzung
api_key = "wRX0tTke3DZ8RLKAMntjZ81LwgNQuSN9"
game_ids = range(900,1200)  # Beispielspiel-IDs
# game_ids = range(1110,1112)  # Beispielspiel-IDs
df = process_games(game_ids, api_key)
df = extract_players_from_summary(df)
df = clean_sort(df)
df = convert_to_polars(df)
df = clean_play_ids(df)
df = add_event_columns(df)
df = correct_posteam(df)
df = clean_yardage(df)
df = add_scoring_play_team(df)
df = add_team_points(df)
df = drop_cols(df)

# DataFrame speichern oder anzeigen
print(df.head())
df.write_csv("games_plays.csv")
# Out:
# Verarbeite Spiel ID: 900
# Fehler beim Abrufen der Drives-Daten für Spiel 900
# Fertig mit Spiel ID: 900
# Verarbeite Spiel ID: 901
# Fehler beim Abrufen der Drives-Daten für Spiel 901
# Fertig mit Spiel ID: 901
# Verarbeite Spiel ID: 902
# Fehler beim Abrufen der Drives-Daten für Spiel 902
# Fertig mit Spiel ID: 902
# Verarbeite Spiel ID: 903
# Fehler beim Abrufen der Drives-Daten für Spiel 903
# Fertig mit Spiel ID: 903
# Verarbeite Spiel ID: 904
# Fehler beim Abrufen der Drives-Daten für Spiel 904
# Fertig mit Spiel ID: 904
# Verarbeite Spiel ID: 905
# Fehler beim Abrufen der Drives-Daten für Spiel 905
# Fertig mit Spiel ID: 905
# Verarbeite Spiel ID: 906
# Fehler beim Abrufen der Drives-Daten für Spiel 906
# Fertig mit Spiel ID: 906
# Verarbeite Spiel ID: 907
# Fehler beim Abrufen der Drives-Daten für Spiel 907
# Fertig mit Spiel ID: 907
# Verarbeite Spiel ID: 908
# Fehler beim Abrufen der Drives-Daten für Spiel 908
# Fertig mit Spiel ID: 908
# Verarbeite Spiel ID: 909
# Fehler beim Abrufen der Drives-Daten für Spiel 909
# Fertig mit Spiel ID: 909
# Verarbeite Spiel ID: 910
# Fehler beim Abrufen der Drives-Daten für Spiel 910
# Fertig mit Spiel ID: 910
# Verarbeite Spiel ID: 911
# Fehler beim Abrufen der Drives-Daten für Spiel 911
# Fertig mit Spiel ID: 911
# Verarbeite Spiel ID: 912
# Fehler beim Abrufen der Drives-Daten für Spiel 912
# Fertig mit Spiel ID: 912
# Verarbeite Spiel ID: 913
# Fehler beim Abrufen der Drives-Daten für Spiel 913
# Fertig mit Spiel ID: 913
# Verarbeite Spiel ID: 914
# Fehler beim Abrufen der Drives-Daten für Spiel 914
# Fertig mit Spiel ID: 914
# Verarbeite Spiel ID: 915
# Fehler beim Abrufen der Drives-Daten für Spiel 915
# Fertig mit Spiel ID: 915
# Verarbeite Spiel ID: 916
# Fehler beim Abrufen der Drives-Daten für Spiel 916
# Fertig mit Spiel ID: 916
# Verarbeite Spiel ID: 917
# Fehler beim Abrufen der Drives-Daten für Spiel 917
# Fertig mit Spiel ID: 917
# Verarbeite Spiel ID: 918
# Fehler beim Abrufen der Drives-Daten für Spiel 918
# Fertig mit Spiel ID: 918
# Verarbeite Spiel ID: 919
# Fehler beim Abrufen der Drives-Daten für Spiel 919
# Fertig mit Spiel ID: 919
# Verarbeite Spiel ID: 920
# Fehler beim Abrufen der Drives-Daten für Spiel 920
# Fertig mit Spiel ID: 920
# Verarbeite Spiel ID: 921
# Fehler beim Abrufen der Drives-Daten für Spiel 921
# Fertig mit Spiel ID: 921
# Verarbeite Spiel ID: 922
# Fehler beim Abrufen der Drives-Daten für Spiel 922
# Fertig mit Spiel ID: 922
# Verarbeite Spiel ID: 923
# Fehler beim Abrufen der Drives-Daten für Spiel 923
# Fertig mit Spiel ID: 923
# Verarbeite Spiel ID: 924
# Fehler beim Abrufen der Drives-Daten für Spiel 924
# Fertig mit Spiel ID: 924
# Verarbeite Spiel ID: 925
# Fehler beim Abrufen der Drives-Daten für Spiel 925
# Fertig mit Spiel ID: 925
# Verarbeite Spiel ID: 926
# Fehler beim Abrufen der Drives-Daten für Spiel 926
# Fertig mit Spiel ID: 926
# Verarbeite Spiel ID: 927
# Fehler beim Abrufen der Drives-Daten für Spiel 927
# Fertig mit Spiel ID: 927
# Verarbeite Spiel ID: 928
# Fehler beim Abrufen der Drives-Daten für Spiel 928
# Fertig mit Spiel ID: 928
# Verarbeite Spiel ID: 929
# Fehler beim Abrufen der Drives-Daten für Spiel 929
# Fertig mit Spiel ID: 929
# Verarbeite Spiel ID: 930
# Fehler beim Abrufen der Drives-Daten für Spiel 930
# Fertig mit Spiel ID: 930
# Verarbeite Spiel ID: 931
# Fehler beim Abrufen der Drives-Daten für Spiel 931
# Fertig mit Spiel ID: 931
# Verarbeite Spiel ID: 932
# Fehler beim Abrufen der Drives-Daten für Spiel 932
# Fertig mit Spiel ID: 932
# Verarbeite Spiel ID: 933
# Fehler beim Abrufen der Drives-Daten für Spiel 933
# Fertig mit Spiel ID: 933
# Verarbeite Spiel ID: 934
# Fehler beim Abrufen der Drives-Daten für Spiel 934
# Fertig mit Spiel ID: 934
# Verarbeite Spiel ID: 935
# Fehler beim Abrufen der Drives-Daten für Spiel 935
# Fertig mit Spiel ID: 935
# Verarbeite Spiel ID: 936
# Fehler beim Abrufen der Drives-Daten für Spiel 936
# Fertig mit Spiel ID: 936
# Verarbeite Spiel ID: 937
# Fehler beim Abrufen der Drives-Daten für Spiel 937
# Fertig mit Spiel ID: 937
# Verarbeite Spiel ID: 938
# Fehler beim Abrufen der Drives-Daten für Spiel 938
# Fertig mit Spiel ID: 938
# Verarbeite Spiel ID: 939
# Fehler beim Abrufen der Drives-Daten für Spiel 939
# Fertig mit Spiel ID: 939
# Verarbeite Spiel ID: 940
# Fehler beim Abrufen der Drives-Daten für Spiel 940
# Fertig mit Spiel ID: 940
# Verarbeite Spiel ID: 941
# Fehler beim Abrufen der Drives-Daten für Spiel 941
# Fertig mit Spiel ID: 941
# Verarbeite Spiel ID: 942
# Fehler beim Abrufen der Drives-Daten für Spiel 942
# Fertig mit Spiel ID: 942
# Verarbeite Spiel ID: 943
# Fehler beim Abrufen der Drives-Daten für Spiel 943
# Fertig mit Spiel ID: 943
# Verarbeite Spiel ID: 944
# Fehler beim Abrufen der Drives-Daten für Spiel 944
# Fertig mit Spiel ID: 944
# Verarbeite Spiel ID: 945
# Fehler beim Abrufen der Drives-Daten für Spiel 945
# Fertig mit Spiel ID: 945
# Verarbeite Spiel ID: 946
# Fehler beim Abrufen der Drives-Daten für Spiel 946
# Fertig mit Spiel ID: 946
# Verarbeite Spiel ID: 947
# Fehler beim Abrufen der Drives-Daten für Spiel 947
# Fertig mit Spiel ID: 947
# Verarbeite Spiel ID: 948
# Fehler beim Abrufen der Drives-Daten für Spiel 948
# Fertig mit Spiel ID: 948
# Verarbeite Spiel ID: 949
# Fehler beim Abrufen der Drives-Daten für Spiel 949
# Fertig mit Spiel ID: 949
# Verarbeite Spiel ID: 950
# Fehler beim Abrufen der Drives-Daten für Spiel 950
# Fertig mit Spiel ID: 950
# Verarbeite Spiel ID: 951
# Fehler beim Abrufen der Drives-Daten für Spiel 951
# Fertig mit Spiel ID: 951
# Verarbeite Spiel ID: 952
# Fehler beim Abrufen der Drives-Daten für Spiel 952
# Fertig mit Spiel ID: 952
# Verarbeite Spiel ID: 953
# Fehler beim Abrufen der Drives-Daten für Spiel 953
# Fertig mit Spiel ID: 953
# Verarbeite Spiel ID: 954
# Fehler beim Abrufen der Drives-Daten für Spiel 954
# Fertig mit Spiel ID: 954
# Verarbeite Spiel ID: 955
# Fehler beim Abrufen der Drives-Daten für Spiel 955
# Fertig mit Spiel ID: 955
# Verarbeite Spiel ID: 956
# Fertig mit Spiel ID: 956
# Verarbeite Spiel ID: 957
# Fertig mit Spiel ID: 957
# Verarbeite Spiel ID: 958
# Fertig mit Spiel ID: 958
# Verarbeite Spiel ID: 959
# Fertig mit Spiel ID: 959
# Verarbeite Spiel ID: 960
# Fertig mit Spiel ID: 960
# Verarbeite Spiel ID: 961
# Fertig mit Spiel ID: 961
# Verarbeite Spiel ID: 962
# Fertig mit Spiel ID: 962
# Verarbeite Spiel ID: 963
# Fertig mit Spiel ID: 963
# Verarbeite Spiel ID: 964
# Fertig mit Spiel ID: 964
# Verarbeite Spiel ID: 965
# Fertig mit Spiel ID: 965
# Verarbeite Spiel ID: 966
# Fertig mit Spiel ID: 966
# Verarbeite Spiel ID: 967
# Fertig mit Spiel ID: 967
# Verarbeite Spiel ID: 968
# Fertig mit Spiel ID: 968
# Verarbeite Spiel ID: 969
# Fertig mit Spiel ID: 969
# Verarbeite Spiel ID: 970
# Fertig mit Spiel ID: 970
# Verarbeite Spiel ID: 971
# Keine Ergebnisdaten verfügbar für Spiel 971.
# Fertig mit Spiel ID: 971
# Verarbeite Spiel ID: 972
# Fertig mit Spiel ID: 972
# Verarbeite Spiel ID: 973
# Fertig mit Spiel ID: 973
# Verarbeite Spiel ID: 974
# Fertig mit Spiel ID: 974
# Verarbeite Spiel ID: 975
# Fertig mit Spiel ID: 975
# Verarbeite Spiel ID: 976
# Fertig mit Spiel ID: 976
# Verarbeite Spiel ID: 977
# Fertig mit Spiel ID: 977
# Verarbeite Spiel ID: 978
# Fertig mit Spiel ID: 978
# Verarbeite Spiel ID: 979
# Fertig mit Spiel ID: 979
# Verarbeite Spiel ID: 980
# Fertig mit Spiel ID: 980
# Verarbeite Spiel ID: 981
# Fertig mit Spiel ID: 981
# Verarbeite Spiel ID: 982
# Fertig mit Spiel ID: 982
# Verarbeite Spiel ID: 983
# Fertig mit Spiel ID: 983
# Verarbeite Spiel ID: 984
# Fertig mit Spiel ID: 984
# Verarbeite Spiel ID: 985
# Fertig mit Spiel ID: 985
# Verarbeite Spiel ID: 986
# Fertig mit Spiel ID: 986
# Verarbeite Spiel ID: 987
# Fertig mit Spiel ID: 987
# Verarbeite Spiel ID: 988
# Fertig mit Spiel ID: 988
# Verarbeite Spiel ID: 989
# Fertig mit Spiel ID: 989
# Verarbeite Spiel ID: 990
# Fertig mit Spiel ID: 990
# Verarbeite Spiel ID: 991
# Fertig mit Spiel ID: 991
# Verarbeite Spiel ID: 992
# Fehler beim Abrufen der Drives-Daten für Spiel 992
# Fertig mit Spiel ID: 992
# Verarbeite Spiel ID: 993
# Fertig mit Spiel ID: 993
# Verarbeite Spiel ID: 994
# Fertig mit Spiel ID: 994
# Verarbeite Spiel ID: 995
# Fertig mit Spiel ID: 995
# Verarbeite Spiel ID: 996
# Fertig mit Spiel ID: 996
# Verarbeite Spiel ID: 997
# Fertig mit Spiel ID: 997
# Verarbeite Spiel ID: 998
# Fertig mit Spiel ID: 998
# Verarbeite Spiel ID: 999
# Fertig mit Spiel ID: 999
# Verarbeite Spiel ID: 1000
# Fertig mit Spiel ID: 1000
# Verarbeite Spiel ID: 1001
# Fertig mit Spiel ID: 1001
# Verarbeite Spiel ID: 1002
# Fertig mit Spiel ID: 1002
# Verarbeite Spiel ID: 1003
# Fertig mit Spiel ID: 1003
# Verarbeite Spiel ID: 1004
# Fertig mit Spiel ID: 1004
# Verarbeite Spiel ID: 1005
# Fertig mit Spiel ID: 1005
# Verarbeite Spiel ID: 1006
# Fertig mit Spiel ID: 1006
# Verarbeite Spiel ID: 1007
# Fertig mit Spiel ID: 1007
# Verarbeite Spiel ID: 1008
# Fertig mit Spiel ID: 1008
# Verarbeite Spiel ID: 1009
# Fertig mit Spiel ID: 1009
# Verarbeite Spiel ID: 1010
# Fertig mit Spiel ID: 1010
# Verarbeite Spiel ID: 1011
# Fertig mit Spiel ID: 1011
# Verarbeite Spiel ID: 1012
# Fertig mit Spiel ID: 1012
# Verarbeite Spiel ID: 1013
# Fertig mit Spiel ID: 1013
# Verarbeite Spiel ID: 1014
# Fertig mit Spiel ID: 1014
# Verarbeite Spiel ID: 1015
# Fertig mit Spiel ID: 1015
# Verarbeite Spiel ID: 1016
# Fertig mit Spiel ID: 1016
# Verarbeite Spiel ID: 1017
# Fertig mit Spiel ID: 1017
# Verarbeite Spiel ID: 1018
# Fertig mit Spiel ID: 1018
# Verarbeite Spiel ID: 1019
# Fertig mit Spiel ID: 1019
# Verarbeite Spiel ID: 1020
# Fertig mit Spiel ID: 1020
# Verarbeite Spiel ID: 1021
# Fertig mit Spiel ID: 1021
# Verarbeite Spiel ID: 1022
# Fertig mit Spiel ID: 1022
# Verarbeite Spiel ID: 1023
# Fertig mit Spiel ID: 1023
# Verarbeite Spiel ID: 1024
# Fertig mit Spiel ID: 1024
# Verarbeite Spiel ID: 1025
# Fertig mit Spiel ID: 1025
# Verarbeite Spiel ID: 1026
# Fertig mit Spiel ID: 1026
# Verarbeite Spiel ID: 1027
# Fertig mit Spiel ID: 1027
# Verarbeite Spiel ID: 1028
# Fertig mit Spiel ID: 1028
# Verarbeite Spiel ID: 1029
# Fertig mit Spiel ID: 1029
# Verarbeite Spiel ID: 1030
# Fehler beim Abrufen der Drives-Daten für Spiel 1030
# Fertig mit Spiel ID: 1030
# Verarbeite Spiel ID: 1031
# Fertig mit Spiel ID: 1031
# Verarbeite Spiel ID: 1032
# Fertig mit Spiel ID: 1032
# Verarbeite Spiel ID: 1033
# Fertig mit Spiel ID: 1033
# Verarbeite Spiel ID: 1034
# Fertig mit Spiel ID: 1034
# Verarbeite Spiel ID: 1035
# Fertig mit Spiel ID: 1035
# Verarbeite Spiel ID: 1036
# Fertig mit Spiel ID: 1036
# Verarbeite Spiel ID: 1037
# Fertig mit Spiel ID: 1037
# Verarbeite Spiel ID: 1038
# Fertig mit Spiel ID: 1038
# Verarbeite Spiel ID: 1039
# Fertig mit Spiel ID: 1039
# Verarbeite Spiel ID: 1040
# Fertig mit Spiel ID: 1040
# Verarbeite Spiel ID: 1041
# Fertig mit Spiel ID: 1041
# Verarbeite Spiel ID: 1042
# Fertig mit Spiel ID: 1042
# Verarbeite Spiel ID: 1043
# Fertig mit Spiel ID: 1043
# Verarbeite Spiel ID: 1044
# Fertig mit Spiel ID: 1044
# Verarbeite Spiel ID: 1045
# Fertig mit Spiel ID: 1045
# Verarbeite Spiel ID: 1046
# Fehler beim Abrufen der Drives-Daten für Spiel 1046
# Fertig mit Spiel ID: 1046
# Verarbeite Spiel ID: 1047
# Fertig mit Spiel ID: 1047
# Verarbeite Spiel ID: 1048
# Fertig mit Spiel ID: 1048
# Verarbeite Spiel ID: 1049
# Fertig mit Spiel ID: 1049
# Verarbeite Spiel ID: 1050
# Fertig mit Spiel ID: 1050
# Verarbeite Spiel ID: 1051
# Fertig mit Spiel ID: 1051
# Verarbeite Spiel ID: 1052
# Fertig mit Spiel ID: 1052
# Verarbeite Spiel ID: 1053
# Fertig mit Spiel ID: 1053
# Verarbeite Spiel ID: 1054
# Fertig mit Spiel ID: 1054
# Verarbeite Spiel ID: 1055
# Fertig mit Spiel ID: 1055
# Verarbeite Spiel ID: 1056
# Fertig mit Spiel ID: 1056
# Verarbeite Spiel ID: 1057
# Fertig mit Spiel ID: 1057
# Verarbeite Spiel ID: 1058
# Fertig mit Spiel ID: 1058
# Verarbeite Spiel ID: 1059
# Fertig mit Spiel ID: 1059
# Verarbeite Spiel ID: 1060
# Fertig mit Spiel ID: 1060
# Verarbeite Spiel ID: 1061
# Fertig mit Spiel ID: 1061
# Verarbeite Spiel ID: 1062
# Fertig mit Spiel ID: 1062
# Verarbeite Spiel ID: 1063
# Fertig mit Spiel ID: 1063
# Verarbeite Spiel ID: 1064
# Fertig mit Spiel ID: 1064
# Verarbeite Spiel ID: 1065
# Fertig mit Spiel ID: 1065
# Verarbeite Spiel ID: 1066
# Fertig mit Spiel ID: 1066
# Verarbeite Spiel ID: 1067
# Fertig mit Spiel ID: 1067
# Verarbeite Spiel ID: 1068
# Fertig mit Spiel ID: 1068
# Verarbeite Spiel ID: 1069
# Fehler beim Abrufen der Drives-Daten für Spiel 1069
# Fertig mit Spiel ID: 1069
# Verarbeite Spiel ID: 1070
# Fehler beim Abrufen der Drives-Daten für Spiel 1070
# Fertig mit Spiel ID: 1070
# Verarbeite Spiel ID: 1071
# Fehler beim Abrufen der Drives-Daten für Spiel 1071
# Fertig mit Spiel ID: 1071
# Verarbeite Spiel ID: 1072
# Fehler beim Abrufen der Drives-Daten für Spiel 1072
# Fertig mit Spiel ID: 1072
# Verarbeite Spiel ID: 1073
# Fehler beim Abrufen der Drives-Daten für Spiel 1073
# Fertig mit Spiel ID: 1073
# Verarbeite Spiel ID: 1074
# Fertig mit Spiel ID: 1074
# Verarbeite Spiel ID: 1075
# Fertig mit Spiel ID: 1075
# Verarbeite Spiel ID: 1076
# Fertig mit Spiel ID: 1076
# Verarbeite Spiel ID: 1077
# Fertig mit Spiel ID: 1077
# Verarbeite Spiel ID: 1078
# Fertig mit Spiel ID: 1078
# Verarbeite Spiel ID: 1079
# Fertig mit Spiel ID: 1079
# Verarbeite Spiel ID: 1080
# Fertig mit Spiel ID: 1080
# Verarbeite Spiel ID: 1081
# Fertig mit Spiel ID: 1081
# Verarbeite Spiel ID: 1082
# Fertig mit Spiel ID: 1082
# Verarbeite Spiel ID: 1083
# Fertig mit Spiel ID: 1083
# Verarbeite Spiel ID: 1084
# Fertig mit Spiel ID: 1084
# Verarbeite Spiel ID: 1085
# Fertig mit Spiel ID: 1085
# Verarbeite Spiel ID: 1086
# Fertig mit Spiel ID: 1086
# Verarbeite Spiel ID: 1087
# Fertig mit Spiel ID: 1087
# Verarbeite Spiel ID: 1088
# Fertig mit Spiel ID: 1088
# Verarbeite Spiel ID: 1089
# Fertig mit Spiel ID: 1089
# Verarbeite Spiel ID: 1090
# Fertig mit Spiel ID: 1090
# Verarbeite Spiel ID: 1091
# Fertig mit Spiel ID: 1091
# Verarbeite Spiel ID: 1092
# Fertig mit Spiel ID: 1092
# Verarbeite Spiel ID: 1093
# Fertig mit Spiel ID: 1093
# Verarbeite Spiel ID: 1094
# Fehler beim Abrufen der Drives-Daten für Spiel 1094
# Fertig mit Spiel ID: 1094
# Verarbeite Spiel ID: 1095
# Fehler beim Abrufen der Drives-Daten für Spiel 1095
# Fertig mit Spiel ID: 1095
# Verarbeite Spiel ID: 1096
# Fehler beim Abrufen der Drives-Daten für Spiel 1096
# Fertig mit Spiel ID: 1096
# Verarbeite Spiel ID: 1097
# Fertig mit Spiel ID: 1097
# Verarbeite Spiel ID: 1098
# Fertig mit Spiel ID: 1098
# Verarbeite Spiel ID: 1099
# Fertig mit Spiel ID: 1099
# Verarbeite Spiel ID: 1100
# Fertig mit Spiel ID: 1100
# Verarbeite Spiel ID: 1101
# Fertig mit Spiel ID: 1101
# Verarbeite Spiel ID: 1102
# Fertig mit Spiel ID: 1102
# Verarbeite Spiel ID: 1103
# Fertig mit Spiel ID: 1103
# Verarbeite Spiel ID: 1104
# Fertig mit Spiel ID: 1104
# Verarbeite Spiel ID: 1105
# Fertig mit Spiel ID: 1105
# Verarbeite Spiel ID: 1106
# Fertig mit Spiel ID: 1106
# Verarbeite Spiel ID: 1107
# Fertig mit Spiel ID: 1107
# Verarbeite Spiel ID: 1108
# Fertig mit Spiel ID: 1108
# Verarbeite Spiel ID: 1109
# Fertig mit Spiel ID: 1109
# Verarbeite Spiel ID: 1110
# Fertig mit Spiel ID: 1110
# Verarbeite Spiel ID: 1111
# Fertig mit Spiel ID: 1111
# Verarbeite Spiel ID: 1112
# Fertig mit Spiel ID: 1112
# Verarbeite Spiel ID: 1113
# Fertig mit Spiel ID: 1113
# Verarbeite Spiel ID: 1114
# Fertig mit Spiel ID: 1114
# Verarbeite Spiel ID: 1115
# Fertig mit Spiel ID: 1115
# Verarbeite Spiel ID: 1116
# Fertig mit Spiel ID: 1116
# Verarbeite Spiel ID: 1117
# Fertig mit Spiel ID: 1117
# Verarbeite Spiel ID: 1118
# Fertig mit Spiel ID: 1118
# Verarbeite Spiel ID: 1119
# Fertig mit Spiel ID: 1119
# Verarbeite Spiel ID: 1120
# Fertig mit Spiel ID: 1120
# Verarbeite Spiel ID: 1121
# Fertig mit Spiel ID: 1121
# Verarbeite Spiel ID: 1122
# Fertig mit Spiel ID: 1122
# Verarbeite Spiel ID: 1123
# Fertig mit Spiel ID: 1123
# Verarbeite Spiel ID: 1124
# Fertig mit Spiel ID: 1124
# Verarbeite Spiel ID: 1125
# Fertig mit Spiel ID: 1125
# Verarbeite Spiel ID: 1126
# Fertig mit Spiel ID: 1126
# Verarbeite Spiel ID: 1127
# Fertig mit Spiel ID: 1127
# Verarbeite Spiel ID: 1128
# Fertig mit Spiel ID: 1128
# Verarbeite Spiel ID: 1129
# Fertig mit Spiel ID: 1129
# Verarbeite Spiel ID: 1130
# Fertig mit Spiel ID: 1130
# Verarbeite Spiel ID: 1131
# Fertig mit Spiel ID: 1131
# Verarbeite Spiel ID: 1132
# Fertig mit Spiel ID: 1132
# Verarbeite Spiel ID: 1133
# Fertig mit Spiel ID: 1133
# Verarbeite Spiel ID: 1134
# Fertig mit Spiel ID: 1134
# Verarbeite Spiel ID: 1135
# Fertig mit Spiel ID: 1135
# Verarbeite Spiel ID: 1136
# Fertig mit Spiel ID: 1136
# Verarbeite Spiel ID: 1137
# Fertig mit Spiel ID: 1137
# Verarbeite Spiel ID: 1138
# Fertig mit Spiel ID: 1138
# Verarbeite Spiel ID: 1139
# Fertig mit Spiel ID: 1139
# Verarbeite Spiel ID: 1140
# Fertig mit Spiel ID: 1140
# Verarbeite Spiel ID: 1141
# Fertig mit Spiel ID: 1141
# Verarbeite Spiel ID: 1142
# Fertig mit Spiel ID: 1142
# Verarbeite Spiel ID: 1143
# Fertig mit Spiel ID: 1143
# Verarbeite Spiel ID: 1144
# Fehler beim Abrufen der Drives-Daten für Spiel 1144
# Fertig mit Spiel ID: 1144
# Verarbeite Spiel ID: 1145
# Fertig mit Spiel ID: 1145
# Verarbeite Spiel ID: 1146
# Fertig mit Spiel ID: 1146
# Verarbeite Spiel ID: 1147
# Fertig mit Spiel ID: 1147
# Verarbeite Spiel ID: 1148
# Fertig mit Spiel ID: 1148
# Verarbeite Spiel ID: 1149
# Fertig mit Spiel ID: 1149
# Verarbeite Spiel ID: 1150
# Fertig mit Spiel ID: 1150
# Verarbeite Spiel ID: 1151
# Fertig mit Spiel ID: 1151
# Verarbeite Spiel ID: 1152
# Fertig mit Spiel ID: 1152
# Verarbeite Spiel ID: 1153
# Fertig mit Spiel ID: 1153
# Verarbeite Spiel ID: 1154
# Fertig mit Spiel ID: 1154
# Verarbeite Spiel ID: 1155
# Fertig mit Spiel ID: 1155
# Verarbeite Spiel ID: 1156
# Fehler beim Abrufen der Drives-Daten für Spiel 1156
# Fertig mit Spiel ID: 1156
# Verarbeite Spiel ID: 1157
# Fertig mit Spiel ID: 1157
# Verarbeite Spiel ID: 1158
# Fehler beim Abrufen der Drives-Daten für Spiel 1158
# Fertig mit Spiel ID: 1158
# Verarbeite Spiel ID: 1159
# Fehler beim Abrufen der Drives-Daten für Spiel 1159
# Fertig mit Spiel ID: 1159
# Verarbeite Spiel ID: 1160
# Fehler beim Abrufen der Drives-Daten für Spiel 1160
# Fertig mit Spiel ID: 1160
# Verarbeite Spiel ID: 1161
# Fehler beim Abrufen der Drives-Daten für Spiel 1161
# Fertig mit Spiel ID: 1161
# Verarbeite Spiel ID: 1162
# Fehler beim Abrufen der Drives-Daten für Spiel 1162
# Fertig mit Spiel ID: 1162
# Verarbeite Spiel ID: 1163
# Fehler beim Abrufen der Drives-Daten für Spiel 1163
# Fertig mit Spiel ID: 1163
# Verarbeite Spiel ID: 1164
# Fehler beim Abrufen der Drives-Daten für Spiel 1164
# Fertig mit Spiel ID: 1164
# Verarbeite Spiel ID: 1165
# Fehler beim Abrufen der Drives-Daten für Spiel 1165
# Fertig mit Spiel ID: 1165
# Verarbeite Spiel ID: 1166
# Fehler beim Abrufen der Drives-Daten für Spiel 1166
# Fertig mit Spiel ID: 1166
# Verarbeite Spiel ID: 1167
# Fehler beim Abrufen der Drives-Daten für Spiel 1167
# Fertig mit Spiel ID: 1167
# Verarbeite Spiel ID: 1168
# Fehler beim Abrufen der Drives-Daten für Spiel 1168
# Fertig mit Spiel ID: 1168
# Verarbeite Spiel ID: 1169
# Fehler beim Abrufen der Drives-Daten für Spiel 1169
# Fertig mit Spiel ID: 1169
# Verarbeite Spiel ID: 1170
# Fehler beim Abrufen der Drives-Daten für Spiel 1170
# Fertig mit Spiel ID: 1170
# Verarbeite Spiel ID: 1171
# Fehler beim Abrufen der Drives-Daten für Spiel 1171
# Fertig mit Spiel ID: 1171
# Verarbeite Spiel ID: 1172
# Fehler beim Abrufen der Drives-Daten für Spiel 1172
# Fertig mit Spiel ID: 1172
# Verarbeite Spiel ID: 1173
# Fehler beim Abrufen der Drives-Daten für Spiel 1173
# Fertig mit Spiel ID: 1173
# Verarbeite Spiel ID: 1174
# Fehler beim Abrufen der Drives-Daten für Spiel 1174
# Fertig mit Spiel ID: 1174
# Verarbeite Spiel ID: 1175
# Fehler beim Abrufen der Drives-Daten für Spiel 1175
# Fertig mit Spiel ID: 1175
# Verarbeite Spiel ID: 1176
# Fehler beim Abrufen der Drives-Daten für Spiel 1176
# Fertig mit Spiel ID: 1176
# Verarbeite Spiel ID: 1177
# Fehler beim Abrufen der Drives-Daten für Spiel 1177
# Fertig mit Spiel ID: 1177
# Verarbeite Spiel ID: 1178
# Fehler beim Abrufen der Drives-Daten für Spiel 1178
# Fertig mit Spiel ID: 1178
# Verarbeite Spiel ID: 1179
# Fehler beim Abrufen der Drives-Daten für Spiel 1179
# Fertig mit Spiel ID: 1179
# Verarbeite Spiel ID: 1180
# Fehler beim Abrufen der Drives-Daten für Spiel 1180
# Fertig mit Spiel ID: 1180
# Verarbeite Spiel ID: 1181
# Fehler beim Abrufen der Drives-Daten für Spiel 1181
# Fertig mit Spiel ID: 1181
# Verarbeite Spiel ID: 1182
# Fehler beim Abrufen der Drives-Daten für Spiel 1182
# Fertig mit Spiel ID: 1182
# Verarbeite Spiel ID: 1183
# Fehler beim Abrufen der Drives-Daten für Spiel 1183
# Fertig mit Spiel ID: 1183
# Verarbeite Spiel ID: 1184
# Fehler beim Abrufen der Drives-Daten für Spiel 1184
# Fertig mit Spiel ID: 1184
# Verarbeite Spiel ID: 1185
# Fehler beim Abrufen der Drives-Daten für Spiel 1185
# Fertig mit Spiel ID: 1185
# Verarbeite Spiel ID: 1186
# Fehler beim Abrufen der Drives-Daten für Spiel 1186
# Fertig mit Spiel ID: 1186
# Verarbeite Spiel ID: 1187
# Fehler beim Abrufen der Drives-Daten für Spiel 1187
# Fertig mit Spiel ID: 1187
# Verarbeite Spiel ID: 1188
# Fehler beim Abrufen der Drives-Daten für Spiel 1188
# Fertig mit Spiel ID: 1188
# Verarbeite Spiel ID: 1189
# Fehler beim Abrufen der Drives-Daten für Spiel 1189
# Fertig mit Spiel ID: 1189
# Verarbeite Spiel ID: 1190
# Fehler beim Abrufen der Drives-Daten für Spiel 1190
# Fertig mit Spiel ID: 1190
# Verarbeite Spiel ID: 1191
# Fehler beim Abrufen der Drives-Daten für Spiel 1191
# Fertig mit Spiel ID: 1191
# Verarbeite Spiel ID: 1192
# Fehler beim Abrufen der Drives-Daten für Spiel 1192
# Fertig mit Spiel ID: 1192
# Verarbeite Spiel ID: 1193
# Fehler beim Abrufen der Drives-Daten für Spiel 1193
# Fertig mit Spiel ID: 1193
# Verarbeite Spiel ID: 1194
# Fehler beim Abrufen der Drives-Daten für Spiel 1194
# Fertig mit Spiel ID: 1194
# Verarbeite Spiel ID: 1195
# Fehler beim Abrufen der Drives-Daten für Spiel 1195
# Fertig mit Spiel ID: 1195
# Verarbeite Spiel ID: 1196
# Fehler beim Abrufen der Drives-Daten für Spiel 1196
# Fertig mit Spiel ID: 1196
# Verarbeite Spiel ID: 1197
# Fehler beim Abrufen der Drives-Daten für Spiel 1197
# Fertig mit Spiel ID: 1197
# Verarbeite Spiel ID: 1198
# Fehler beim Abrufen der Drives-Daten für Spiel 1198
# Fertig mit Spiel ID: 1198
# Verarbeite Spiel ID: 1199
# Fehler beim Abrufen der Drives-Daten für Spiel 1199
# Fertig mit Spiel ID: 1199
# shape: (5, 65)
# ┌───────┬────────┬────────────┬────────────┬───┬────────────┬────────────┬────────────┬────────────┐
# │ index ┆ season ┆ competitio ┆ competitio ┆ … ┆ away_team_ ┆ posteam_sc ┆ defteam_sc ┆ score_diff │
# │ ---   ┆ ---    ┆ n_id       ┆ n_name     ┆   ┆ score      ┆ ore        ┆ ore        ┆ erential   │
# │ u32   ┆ i64    ┆ ---        ┆ ---        ┆   ┆ ---        ┆ ---        ┆ ---        ┆ ---        │
# │       ┆        ┆ i64        ┆ str        ┆   ┆ i32        ┆ i32        ┆ i32        ┆ i32        │
# ╞═══════╪════════╪════════════╪════════════╪═══╪════════════╪════════════╪════════════╪════════════╡
# │ 1     ┆ 2024   ┆ 2          ┆ FlagWC     ┆ … ┆ 0          ┆ 0          ┆ 0          ┆ 0          │
# │ 2     ┆ 2024   ┆ 2          ┆ FlagWC     ┆ … ┆ 0          ┆ 0          ┆ 0          ┆ 0          │
# │ 3     ┆ 2024   ┆ 2          ┆ FlagWC     ┆ … ┆ 0          ┆ 0          ┆ 0          ┆ 0          │
# │ 4     ┆ 2024   ┆ 2          ┆ FlagWC     ┆ … ┆ 0          ┆ 0          ┆ 0          ┆ 0          │
# │ 5     ┆ 2024   ┆ 2          ┆ FlagWC     ┆ … ┆ 6          ┆ 6          ┆ 0          ┆ 6          │
# └───────┴────────┴────────────┴────────────┴───┴────────────┴────────────┴────────────┴────────────┘

# %%
# Beispiel-Aufruf
team_ids = range(1, 101)
api_key = "wRX0tTke3DZ8RLKAMntjZ81LwgNQuSN9"
players_df = fetch_team_players(team_ids, api_key)

# Ausgabe des DataFrames
print(players_df)
players_df.write_csv("team_roster.csv")
# Out:
# Fetching data for team ID: 1
# Successfully fetched data for team ID 1 (Finland)
# Fetching data for team ID: 2
# No players found for team ID: 2 or invalid response format.
# Fetching data for team ID: 3
# No players found for team ID: 3 or invalid response format.
# Fetching data for team ID: 4
# Successfully fetched data for team ID 4 (USA)
# Fetching data for team ID: 5
# No players found for team ID: 5 or invalid response format.
# Fetching data for team ID: 6
# No players found for team ID: 6 or invalid response format.
# Fetching data for team ID: 7
# Successfully fetched data for team ID 7 (Australia)
# Fetching data for team ID: 8
# Successfully fetched data for team ID 8 (France)
# Fetching data for team ID: 9
# Successfully fetched data for team ID 9 (Sweden)
# Fetching data for team ID: 10
# Successfully fetched data for team ID 10 (Ireland)
# Fetching data for team ID: 11
# Successfully fetched data for team ID 11 (Mexico)
# Fetching data for team ID: 12
# Successfully fetched data for team ID 12 (Canada)
# Fetching data for team ID: 13
# Successfully fetched data for team ID 13 (Italy)
# Fetching data for team ID: 14
# Successfully fetched data for team ID 14 (Denmark)
# Fetching data for team ID: 15
# Successfully fetched data for team ID 15 (Korea)
# Fetching data for team ID: 16
# Successfully fetched data for team ID 16 (Japan)
# Fetching data for team ID: 17
# Successfully fetched data for team ID 17 (Germany)
# Fetching data for team ID: 18
# Successfully fetched data for team ID 18 (Brazil)
# Fetching data for team ID: 19
# Successfully fetched data for team ID 19 (Finland)
# Fetching data for team ID: 20
# Successfully fetched data for team ID 20 (Poland)
# Fetching data for team ID: 21
# Successfully fetched data for team ID 21 (Great Britain)
# Fetching data for team ID: 22
# Successfully fetched data for team ID 22 (Panama)
# Fetching data for team ID: 23
# Successfully fetched data for team ID 23 (Czechia)
# Fetching data for team ID: 24
# Successfully fetched data for team ID 24 (Israel)
# Fetching data for team ID: 25
# Successfully fetched data for team ID 25 (Austria)
# Fetching data for team ID: 26
# Successfully fetched data for team ID 26 (Spain)
# Fetching data for team ID: 27
# Successfully fetched data for team ID 27 (New Zealand)
# Fetching data for team ID: 28
# Successfully fetched data for team ID 28 (Switzerland)
# Fetching data for team ID: 29
# Successfully fetched data for team ID 29 (USA)
# Fetching data for team ID: 30
# Successfully fetched data for team ID 30 (Spain)
# Fetching data for team ID: 31
# Successfully fetched data for team ID 31 (Brazil)
# Fetching data for team ID: 32
# Successfully fetched data for team ID 32 (Serbia)
# Fetching data for team ID: 33
# Successfully fetched data for team ID 33 (Mexico)
# Fetching data for team ID: 34
# Successfully fetched data for team ID 34 (Australia)
# Fetching data for team ID: 35
# Successfully fetched data for team ID 35 (Chile)
# Fetching data for team ID: 36
# Successfully fetched data for team ID 36 (Cameroon)
# Fetching data for team ID: 37
# Successfully fetched data for team ID 37 (Germany)
# Fetching data for team ID: 38
# Successfully fetched data for team ID 38 (Great Britain)
# Fetching data for team ID: 39
# Successfully fetched data for team ID 39 (Sweden)
# Fetching data for team ID: 40
# Successfully fetched data for team ID 40 (Georgia)
# Fetching data for team ID: 41
# Successfully fetched data for team ID 41 (Austria)
# Fetching data for team ID: 42
# Successfully fetched data for team ID 42 (Switzerland)
# Fetching data for team ID: 43
# Successfully fetched data for team ID 43 (Ukraine)
# Fetching data for team ID: 44
# Successfully fetched data for team ID 44 (Poland)
# Fetching data for team ID: 45
# Successfully fetched data for team ID 45 (Italy)
# Fetching data for team ID: 46
# Successfully fetched data for team ID 46 (Canada)
# Fetching data for team ID: 47
# Skipping team ID: 47 - Response is not in JSON format.
# Fetching data for team ID: 48
# Successfully fetched data for team ID 48 (Singapore)
# Fetching data for team ID: 49
# Successfully fetched data for team ID 49 (Panama)
# Fetching data for team ID: 50
# Successfully fetched data for team ID 50 (New Zealand)
# Fetching data for team ID: 51
# Successfully fetched data for team ID 51 (Czechia)
# Fetching data for team ID: 52
# Successfully fetched data for team ID 52 (Korea)
# Fetching data for team ID: 53
# Successfully fetched data for team ID 53 (Israel)
# Fetching data for team ID: 54
# Successfully fetched data for team ID 54 (Denmark)
# Fetching data for team ID: 55
# Successfully fetched data for team ID 55 (Ireland)
# Fetching data for team ID: 56
# Successfully fetched data for team ID 56 (India)
# Fetching data for team ID: 57
# Successfully fetched data for team ID 57 (Japan)
# Fetching data for team ID: 58
# Successfully fetched data for team ID 58 (France)
# Fetching data for team ID: 59
# Successfully fetched data for team ID 59 (Kuwait)
# Fetching data for team ID: 60
# Successfully fetched data for team ID 60 (Argentina)
# Fetching data for team ID: 61
# Skipping team ID: 61 - Response is not in JSON format.
# Fetching data for team ID: 62
# Skipping team ID: 62 - Response is not in JSON format.
# Fetching data for team ID: 63
# Skipping team ID: 63 - Response is not in JSON format.
# Fetching data for team ID: 64
# Skipping team ID: 64 - Response is not in JSON format.
# Fetching data for team ID: 65
# Skipping team ID: 65 - Response is not in JSON format.
# Fetching data for team ID: 66
# Skipping team ID: 66 - Response is not in JSON format.
# Fetching data for team ID: 67
# Skipping team ID: 67 - Response is not in JSON format.
# Fetching data for team ID: 68
# Skipping team ID: 68 - Response is not in JSON format.
# Fetching data for team ID: 69
# Skipping team ID: 69 - Response is not in JSON format.
# Fetching data for team ID: 70
# Skipping team ID: 70 - Response is not in JSON format.
# Fetching data for team ID: 71
# Skipping team ID: 71 - Response is not in JSON format.
# Fetching data for team ID: 72
# Skipping team ID: 72 - Response is not in JSON format.
# Fetching data for team ID: 73
# Skipping team ID: 73 - Response is not in JSON format.
# Fetching data for team ID: 74
# Skipping team ID: 74 - Response is not in JSON format.
# Fetching data for team ID: 75
# Skipping team ID: 75 - Response is not in JSON format.
# Fetching data for team ID: 76
# Skipping team ID: 76 - Response is not in JSON format.
# Fetching data for team ID: 77
# Skipping team ID: 77 - Response is not in JSON format.
# Fetching data for team ID: 78
# Skipping team ID: 78 - Response is not in JSON format.
# Fetching data for team ID: 79
# Skipping team ID: 79 - Response is not in JSON format.
# Fetching data for team ID: 80
# Skipping team ID: 80 - Response is not in JSON format.
# Fetching data for team ID: 81
# Skipping team ID: 81 - Response is not in JSON format.
# Fetching data for team ID: 82
# Skipping team ID: 82 - Response is not in JSON format.
# Fetching data for team ID: 83
# Skipping team ID: 83 - Response is not in JSON format.
# Fetching data for team ID: 84
# Skipping team ID: 84 - Response is not in JSON format.
# Fetching data for team ID: 85
# Skipping team ID: 85 - Response is not in JSON format.
# Fetching data for team ID: 86
# Skipping team ID: 86 - Response is not in JSON format.
# Fetching data for team ID: 87
# Skipping team ID: 87 - Response is not in JSON format.
# Fetching data for team ID: 88
# Skipping team ID: 88 - Response is not in JSON format.
# Fetching data for team ID: 89
# Skipping team ID: 89 - Response is not in JSON format.
# Fetching data for team ID: 90
# Skipping team ID: 90 - Response is not in JSON format.
# Fetching data for team ID: 91
# Skipping team ID: 91 - Response is not in JSON format.
# Fetching data for team ID: 92
# Skipping team ID: 92 - Response is not in JSON format.
# Fetching data for team ID: 93
# Skipping team ID: 93 - Response is not in JSON format.
# Fetching data for team ID: 94
# Skipping team ID: 94 - Response is not in JSON format.
# Fetching data for team ID: 95
# Skipping team ID: 95 - Response is not in JSON format.
# Fetching data for team ID: 96
# Skipping team ID: 96 - Response is not in JSON format.
# Fetching data for team ID: 97
# Skipping team ID: 97 - Response is not in JSON format.
# Fetching data for team ID: 98
# Skipping team ID: 98 - Response is not in JSON format.
# Fetching data for team ID: 99
# Skipping team ID: 99 - Response is not in JSON format.
# Fetching data for team ID: 100
# Skipping team ID: 100 - Response is not in JSON format.
# shape: (644, 6)
# ┌───────────┬───────────┬─────────────────────┬────────────────┬──────────┬────────────────────┐
# │ Team      ┆ Player ID ┆ Name                ┆ Uniform Number ┆ Position ┆ Club               │
# │ ---       ┆ ---       ┆ ---                 ┆ ---            ┆ ---      ┆ ---                │
# │ str       ┆ i64       ┆ str                 ┆ str            ┆ str      ┆ str                │
# ╞═══════════╪═══════════╪═════════════════════╪════════════════╪══════════╪════════════════════╡
# │ Finland   ┆ 745       ┆ Alexander Wasiljeff ┆ 2              ┆ DB       ┆ Helsinki FlagLions │
# │ Finland   ┆ 746       ┆ Pekka Rantala       ┆ 4              ┆ DB       ┆ free agent         │
# │ Finland   ┆ 747       ┆ Jaakko Jokinen      ┆ 5              ┆ DB       ┆ Helsinki Roosters  │
# │ Finland   ┆ 748       ┆ Phung Nguyen        ┆ 6              ┆ WR       ┆ Helsinki FlagLions │
# │ Finland   ┆ 749       ┆ Miro Kadmiry        ┆ 7              ┆ QB       ┆ Helsinki FlagLions │
# │ …         ┆ …         ┆ …                   ┆ …              ┆ …        ┆ …                  │
# │ Argentina ┆ 648       ┆ Marcelo Steinborn   ┆ 23             ┆ WR       ┆ Jabalíes           │
# │ Argentina ┆ 649       ┆ Gianluca Salatino   ┆ 40             ┆ DB       ┆ Cruzados           │
# │ Argentina ┆ 650       ┆ Juan Manuel Alonso  ┆ 44             ┆ QB       ┆ Jabalíes           │
# │ Argentina ┆ 651       ┆ Tomás Kouba         ┆ 83             ┆ WR       ┆ Corsarios          │
# │ Argentina ┆ 652       ┆ Guido Dworkind      ┆ 85             ┆ C        ┆ Tiburones          │
# └───────────┴───────────┴─────────────────────┴────────────────┴──────────┴────────────────────┘
